# %%
from failure_recovery import incident_status_count
from datetime import datetime
from zoneinfo import ZoneInfo

# %%
# Define tz-aware start and end dates using zoneinfo
start_date = datetime(2023, 7, 11, tzinfo=ZoneInfo('UTC'))   # Start date with UTC timezone
end_date = datetime(2024, 8, 31, tzinfo=ZoneInfo('UTC'))   # End date with UTC timezone

services = ['API-OpenAI', 'ChatGPT', 'DALL·E', 'Playground', 'API-Anthropic', 'Claude', 'Console', 'Character.AI']

incident_status_count(start_date, end_date, services)
# Out:
# Filtered DataFrame:
#       incident_id                                     Incident_Title  \
# 180  ssg8fh7sfyz3                  Unexpected responses from ChatGPT
# 191  n38dwwksfkv9          Elevated errors affecting API and ChatGPT
# 212  q58417g6n5r7            Increased errors across API and ChatGPT
# 215  n254wyd7nml7                 Elevated Errors on API and ChatGPT
# 224  00fpy0yxrx1q                Major Outage across ChatGPT and API
# 228  fk0tcbydtybr                                Elevated API Errors
# 265  mdbx834gwswg               Partial outage for GPT-4o free users
# 290  w20mcckg1748                         Elevated errors in ChatGPT
# 455  l2fmf12vvkg3                   Degraded performance for ChatGPT
# 497  s9d5cv5jcy7x  Elevated error rates for ChatGPT and Platform API
# 518  hrs6n7lcr2mm                         Elevated errors on ChatGPT
# 523  qvp3rhvc3vwk             ChatGPT is unavailable for some users.
#
# ...
