# %%
from datetime import datetime
from zoneinfo import ZoneInfo
from  llm_analysis.server.scripts.analysis_modules.daily_availability import analyze_daily_availability
from  llm_analysis.server.scripts.analysis_modules.incident_outage import timeline_incident_outage
from  llm_analysis.server.scripts.analysis_modules.status_combinations import analyze_status_combinations
from llm_analysis.server.scripts.analysis_modules.monthly_overview import analyze_monthly_overview
from llm_analysis.server.scripts.analysis_modules.daily_overview import analyze_daily_overview
from llm_analysis.server.scripts.analysis_modules.status_combinations import analyze_status_combinations
from llm_analysis.server.scripts.analysis_modules.mttr_distribution import analyze_mttr_distribution
from llm_analysis.server.scripts.analysis_modules.mtbf_distribution import analyze_mtbf_distribution
from llm_analysis.server.scripts.analysis_modules.resolution_activities import analyze_resolution_activities
from llm_analysis.server.scripts.analysis_modules.daily_availability import analyze_daily_availability
from llm_analysis.server.scripts.analysis_modules.cooccurrence_matrix import analyze_outage_cooccurrence_matrix
from llm_analysis.server.scripts.analysis_modules.coocurrence_probability import analyze_cooccurrence_probability
from llm_analysis.server.scripts.analysis_modules.outage_analysis import analyze_service_outages
from llm_analysis.server.scripts.analysis_modules.service_incidents import analyze_service_incidents
from llm_analysis.server.scripts.analysis_modules.auto_correlations import analyze_autocorrelation
from llm_analysis.server.scripts.analysis_modules.mttr_boxplot import analyze_mttr_boxplot
from llm_analysis.server.scripts.analysis_modules.mtbf_boxplot import analyze_mtbf_boxplot
from llm_analysis.server.scripts.analysis_modules.mttr_provider import analyze_mttr_provider
from llm_analysis.server.scripts.analysis_modules.mtbf_provider import analyze_mtbf_provider
import matplotlib.pyplot as plt

# %matplotlib inline

# Define tz-aware start and end dates using zoneinfo
start_date = datetime(2023, 1, 10)  # Start date with UTC timezone
end_date = datetime(2024, 12, 1)  # End date with UTC timezone

services = ['OpenAI:API', 'OpenAI:ChatGPT', 'OpenAI:DALL-E', 'OpenAI:Playground', 'Anthropic:API', 'Anthropic:Claude', 'Anthropic:Console', 'Character.AI:Character.AI', 'StabilityAI:REST', 'StabilityAI:gRPC', 'StabilityAI:Assistant']

analyze_cooccurrence_probability(start_date, end_date, services)
# Out:
# Selected Services Mapped: ['api', 'chatgpt', 'labs', 'playground', 'api.anthropic.com', 'claude.ai', 'console.anthropic.com', 'character.ai', 'StabilityAI:REST', 'StabilityAI:gRPC', 'StabilityAI:Assistant']
# Pivot shape before selecting columns: (600, 11)
# Column names before selecting: ['api', 'api.anthropic.com', 'character.ai', 'chatgpt', 'claude.ai', 'console.anthropic.com', 'labs', 'playground', 'StabilityAI:REST', 'StabilityAI:gRPC', 'StabilityAI:Assistant']
# Pivot shape after selecting columns: (600, 11)
# Column names after selecting: ['api', 'chatgpt', 'labs', 'playground', 'api.anthropic.com', 'claude.ai', 'console.anthropic.com', 'character.ai', 'StabilityAI:REST', 'StabilityAI:gRPC', 'StabilityAI:Assistant']
# Amount of nonzero values in the pivot table: 279
# Amount of zero values in the pivot table: 6321
# Outage Probability DataFrame:
#                           api  chatgpt   labs  playground  api.anthropic.com  \
# ...

# %%
from datetime import datetime
from zoneinfo import ZoneInfo
from  llm_analysis.server.scripts.analysis_modules.daily_availability import analyze_daily_availability
from  llm_analysis.server.scripts.analysis_modules.incident_outage import timeline_incident_outage
from  llm_analysis.server.scripts.analysis_modules.status_combinations import analyze_status_combinations
from llm_analysis.server.scripts.analysis_modules.monthly_overview import analyze_monthly_overview
from llm_analysis.server.scripts.analysis_modules.daily_overview import analyze_daily_overview
from llm_analysis.server.scripts.analysis_modules.status_combinations import analyze_status_combinations
from llm_analysis.server.scripts.analysis_modules.mttr_distribution import analyze_mttr_distribution
from llm_analysis.server.scripts.analysis_modules.mtbf_distribution import analyze_mtbf_distribution
from llm_analysis.server.scripts.analysis_modules.resolution_activities import analyze_resolution_activities
from llm_analysis.server.scripts.analysis_modules.daily_availability import analyze_daily_availability
from llm_analysis.server.scripts.analysis_modules.cooccurrence_matrix import analyze_outage_cooccurrence_matrix
from llm_analysis.server.scripts.analysis_modules.coocurrence_probability import analyze_cooccurrence_probability
from llm_analysis.server.scripts.analysis_modules.outage_analysis import analyze_service_outages
from llm_analysis.server.scripts.analysis_modules.service_incidents import analyze_service_incidents
from llm_analysis.server.scripts.analysis_modules.auto_correlations import analyze_autocorrelation
from llm_analysis.server.scripts.analysis_modules.mttr_boxplot import analyze_mttr_boxplot
from llm_analysis.server.scripts.analysis_modules.mtbf_boxplot import analyze_mtbf_boxplot
from llm_analysis.server.scripts.analysis_modules.mttr_provider import analyze_mttr_provider
from llm_analysis.server.scripts.analysis_modules.mtbf_provider import analyze_mtbf_provider
import matplotlib.pyplot as plt

# %matplotlib inline

# Define tz-aware start and end dates using zoneinfo
start_date = datetime(2023, 1, 10)  # Start date with UTC timezone
end_date = datetime(2024, 12, 1)  # End date with UTC timezone

services = ['OpenAI:API', 'OpenAI:ChatGPT', 'OpenAI:DALL-E', 'OpenAI:Playground', 'Anthropic:API', 'Anthropic:Claude', 'Anthropic:Console', 'Character.AI:Character.AI', 'StabilityAI:REST', 'StabilityAI:gRPC', 'StabilityAI:Assistant']

#show all plots
analyze_autocorrelation(start_date, end_date, services)
analyze_daily_availability(start_date, end_date, services)
analyze_mtbf_boxplot(start_date, end_date, services)
analyze_mtbf_provider(start_date, end_date, services)
analyze_mttr_boxplot(start_date, end_date, services)
analyze_mttr_provider(start_date, end_date, services)
analyze_status_combinations(start_date, end_date, services)
analyze_monthly_overview(start_date, end_date, services)
analyze_daily_overview(start_date, end_date, services)
analyze_resolution_activities(start_date, end_date, services)
analyze_outage_cooccurrence_matrix(start_date, end_date, services)
analyze_cooccurrence_probability(start_date, end_date, services)
#analyze_service_outages(start_date, end_date, services)
analyze_service_incidents(start_date, end_date, services)
analyze_mttr_distribution(start_date, end_date, services)
analyze_mtbf_distribution(start_date, end_date, services)
timeline_incident_outage(start_date, end_date, services)
# Out:
# Available columns in data:
# ['incident_id', 'Incident_Title', 'incident_impact_level', 'Incident_color', 'provider', 'Playground', 'API', 'DALL-E', 'ChatGPT', 'api.anthropic.com', 'claude.ai', 'console.anthropic.com', 'Character.AI', 'REST API', 'gRPC API', 'Stable Assistant', 'investigating_flag', 'investigating_timestamp', 'investigating_description', 'identified_flag', 'identified_timestamp', 'identified_description', 'monitoring_flag', 'monitoring_timestamp', 'monitoring_description', 'resolved_flag', 'resolved_timestamp', 'resolved_description', 'postmortem_flag', 'postmortem_timestamp', 'postmortem_description', 'start_timestamp', 'close_timestamp', 'time_span', 'over_one_day', 'StabilityAI']
# Available providers in data:
# API-OpenAI: ['openai']
# ChatGPT: ['openai']
# DALL-E: []
# Playground: ['openai']
# API-Anthropic: ['anthropic']
# Claude: ['anthropic']
# Console: ['anthropic']
# Character.AI: ['character']
# REST API: ['StabilityAI']
# gRPC API: ['StabilityAI']
# ...
